# %% [markdown]
# Author : Himanshu Gullaiya <br>
# Source : Pierian Data

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread('00-puppy.jpg')
img = cv2.resize(img,(0,0), fx = 0.5, fy = 0.5)

# %%
while True:
    cv2.imshow("Puppy", img)
    if cv2.waitKey(1) in (ord('q'), 27):
        break
cv2.destroyAllWindows()

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
flipped = cv2.flip(img_rgb, 1)

# %%
plt.imshow(img)
cv2.imwrite("newimage.jpg",img)
# Out:
# True

# %%
imm = cv2.imread('newimage.jpg')

# %%
while True:
    cv2.imshow("Puppy", imm)
    if cv2.waitKey(1) in (ord('q'), 27):
        break
cv2.destroyAllWindows()

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(img)

# %%
a = np.ones((500,500,3))

# %%
plt.imshow(a)

# %%
a[:,:,0] = 255
a[:,:,1] = 0
a[:,:,2] = 255

plt.imshow(a)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_img = np.zeros((500,500,3), dtype = np.int16)
plt.imshow(test_img)

# %%
test_rect_img = cv2.rectangle(test_img, pt1 = (490,10), pt2 = (400,100), color = (0,255,0), thickness = -1)

# %%
plt.imshow(test_rect_img)

# %%
a = np.array([[100,300], [200,200], [400,300], [200,400]], dtype = np.int32)

# %%
b = cv2.polylines(test_rect_img , [a], isClosed = True, color = (255,0,0), thickness = 5)

# %%
plt.imshow(b)

# %%
try:
    plt.imshow(aa)
except:
    pass
